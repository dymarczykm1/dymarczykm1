# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# Data comes from HUD in 2021
df = pd.read_csv('https://raw.githubusercontent.com/dymarczykm1/dymarczykm1/main/Data/HECM.csv')

# Setting the seaborn style
sns.set(style='darkgrid', palette='deep')

# Removing column truncation and 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
# The most commonly issued HECM types in 2021 were traditional or refinance

plt.figure(figsize = (15,8))
sns.countplot(data=df, x='Hecm Type');

# %%
# Most common type of rate for issued HECM was adjustable

plt.figure(figsize = (15,8))
sns.countplot(data=df, x='Rate Type');

# %%
# Initial principal limit defines the maximum amount a borrower using a reverse mortgage can receive from the loan. 
# this amount will tend to be a substantially lower amount than the home's appraised market value

#The reverse mortgage maximum claim amount (MCA) is used to calculate proceeds and is equal to either 
# the appraised value of the home or the FHA lending limit, whichever is less.

# This distribution is showing they typically lend between 55% to 60% of the MCA value

for index, row in adjustable_df.iterrows():
    x = adjustable_df['Initial Principal Limit'] / adjustable_df['Maximum Claim Amount']

plt.figure(figsize=(10, 8))
sns.histplot(x);

# %%
# Let's see number of issuance by state in 2021

by_state = df.groupby(by='Property State').count().reset_index()
result = by_state.sort_values(by='Property County', ascending=False)

plt.figure(figsize = (15,8))
ax = sns.barplot(data=result, x='Property State', y='Property County')
ax.set_ylabel("Count");
