# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\MADYMA\Desktop\Python\HECM.csv')

#Setting the seaborn style
sns.set(style='darkgrid', palette='deep')

#Removing column truncation and 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
# Most commonly issued HECM by number of issues

plt.figure(figsize = (15,8))
sns.countplot(data=df, x='Hecm Type');

# %%
# Most common rate type. Signifcant amount are adjustable

plt.figure(figsize = (15,8))
sns.countplot(data=df, x='Rate Type');

# %%
# Most common rate type. Signifcant amount are adjustable

plt.figure(figsize = (15,8))
sns.countplot(data=df, x='Rate Type');

# %%
# Most common rate type. Signifcant amount are adjustable

adjustable_df = df.loc[df['Rate Type'] == 'Adjustable',[
    'Interest Rate', 'Initial Principal Limit', 'Maximum Claim Amount', 'Rate Type']]

# %%
adjustable_df

# %%
new_rows = []
for index, row in adjustable_df.iterrows():
    x = adjustable_df['Initial Principal Limit'] / adjustable_df['Maximum Claim Amount']
    #df_new = adjustable_df.append(pd.DataFrame(new_rows, columns=adjustable_df.columns))

# %%
x
